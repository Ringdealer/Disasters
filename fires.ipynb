# %%
from io import StringIO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import sys
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import data_munging as cleaner

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Loverboy\\PycharmProjects\\ForestFires'

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df1 = pd.read_csv('blazes/fires.csv', skipinitialspace = True)

# %%
df = df1

# %%
df.columns = ['Cause', 'Coordinates', 'Date', 'Fuels Involved', 'Location', 'Incident Type', 'Perimeter', 'Personnel Involved', 'Area Contained']

# %%
df.head(100)
# Out:
#                                             Cause  \
# 0                                             NaN
# 1   Saturday August 15th, 2020 approx.   07:15 AM
# 2                                       Lightning
# 3     Friday August 14th, 2020 approx.   12:30 PM
# 4   Thursday August 13th, 2020 approx.   07:00 PM
# 5     Friday August 14th, 2020 approx.   05:10 PM
# 6                                       Lightning
# 7                                       Lightning
# 8                    Unknown, Under Investigation
# 9                                           Human
# 10                                        Unknown
# 11           32.237 latitude, -110.534 longitude
# 12                                      Lightning
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# ...

# %%
df = cleaner.convert_to_int(df, 'Perimeter', '^[0-9]{1,2}%$|100%$')

# %%
# df.rename(columns = {'Perimeter':'Perimeter (%)'}, inplace=True)
df.head()
# Out:
#                                            Cause  \
# 0                                            NaN
# 1  Saturday August 15th, 2020 approx.   07:15 AM
# 2                                      Lightning
# 3    Friday August 14th, 2020 approx.   12:30 PM
# 4  Thursday August 13th, 2020 approx.   07:00 PM
#
#                             Coordinates  \
# 0                                   NaN
# 1                                   NaN
# 2  33.667 latitude, -105.629 longitude
# 3                                   NaN
# 4                                   NaN
#
#                                             Date Fuels Involved  Location  \
# 0                                            NaN            NaN       NaN
# 1          Tyler Brown, Texas A&M Forest Service            NaN  Wildfire
# 2   Tuesday August 04th, 2020 approx.   04:30 PM            NaN  Wildfire
# 3       Stephen Tanner, Texas A&M Forest Service            NaN  Wildfire
# ...

# %%
# df = cleaner.convert_to_int(df, 'Area Contained', '\d+')

# %%
print(df['Perimeter'].apply(type))
# Out:
# 0      <class 'float'>
# 1      <class 'float'>
# 2        <class 'int'>
# 3      <class 'float'>
# 4      <class 'float'>
# 5      <class 'float'>
# 6        <class 'int'>
# 7        <class 'int'>
# 8      <class 'float'>
# 9        <class 'int'>
# 10       <class 'str'>
# 11       <class 'int'>
# 12       <class 'str'>
# 13     <class 'float'>
# 14     <class 'float'>
# 15     <class 'float'>
# 16     <class 'float'>
# 17     <class 'float'>
# 18     <class 'float'>
# 19     <class 'float'>
# 20     <class 'float'>
# 21       <class 'int'>
# 22       <class 'int'>
# 23       <class 'int'>
# 24       <class 'int'>
# 25       <class 'str'>
# 26     <class 'float'>
# 27     <class 'float'>
# 28       <class 'int'>
# 29       <class 'int'>
# 30       <class 'int'>
# 31       <class 'int'>
# 32       <class 'int'>
# 33       <class 'str'>
# 34       <class 'int'>
# 35       <class 'int'>
# 36       <class 'int'>
# 37       <class 'int'>
# 38       <class 'int'>
# 39       <class 'int'>
# ...

# %%
df.shape
# Out:
# (107, 9)
