# %%
# Standard library imports
from io import StringIO
import importlib
import math
import numpy as np
import os
import pandas as pd
import pdb
import re
import regex
import sys 

# Third party imports
import dateparser
import reverse_geocoder as rg

# Local application imports
import mender_tools as mt

# %% [markdown]
# # Reading the csv file into a dataframe

# %%
df = pd.read_csv('blazes/fires.csv')

# %% [markdown]
# # Set options to display all rows and columns in Jupyter notebook

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Checking out the dataframe

# %%
df.shape
# Out:
# (109, 10)

# %%
df.dtypes
# Out:
# cause            object
# coordinates      object
# day              object
# fuelsinvolved    object
# incident         object
# incidentype      object
# location         object
# perimeter        object
# personnel        object
# size             object
# dtype: object

# %%
df.head()
# Out:
#                                            cause  \
# 0  Saturday August 15th, 2020 approx.   07:15 AM
# 1                                      Lightning
# 2                                      Powerline
# 3                                            NaN
# 4                                            NaN
#
#                             coordinates  \
# 0                                   NaN
# 1   33.544 latitude, -110.42 longitude
# 2  30.863 latitude, -100.548 longitude
# 3                                   NaN
# 4                                   NaN
#
#                                              day  \
# 0          Tyler Brown, Texas A&M Forest Service
# 1  Saturday August 01st, 2020 approx.   04:30 PM
# 2  Thursday August 13th, 2020 approx.   03:15 PM
# 3                                            NaN
# 4                                            NaN
#
#                                                                                                                                                                                                  fuelsinvolved  \
# 0                                                                                                                                                                                                          NaN
# 1  Primary carrier of the fire is currently the timber litter, grass and light brush associated with the under story of the ponderosa pine forest. Oak scrub is involved on the western edge of the burn area.
# 2                                                                                                                                                                                                          NaN
# 3                                                                                                                                                                                                          NaN
# 4                                                                                                                                                                                                          NaN
#
#                  incident incidentype                             location  \
# 0            Chimney Fire    Wildfire  32.722 latitude, -99.481 longitude
# 1  Cassadore Springs Fire    Wildfire     11 miles north of San Carlos, AZ
# 2           Bucholtz Fire    Wildfire             5 miles east of Eldorado
# 3                     NaN         NaN                                  NaN
# 4                     NaN         NaN                                  NaN
#
#   perimeter  personnel          size
# 0       NaN  600 Acres           40%
# 1       90%        243  21,284 Acres
# 2       NaN   73 Acres          100%
# 3       NaN        NaN           NaN
# 4       NaN        NaN           NaN

# %% [markdown]
# # Renaming columns names

# %%
df.columns
# Out:
# Index(['cause', 'coordinates', 'day', 'fuelsinvolved', 'incident',
#        'incidentype', 'location', 'perimeter', 'personnel', 'size'],
#       dtype='object')

# %%
df.columns = ['Cause', 'Coordinates', 'Date', 'Fuels Involved', 'Incident', 'Incident Type', 'Location', 'Perimeter Contained (%)', 'Personnel Involved', 'Fire Size (Acres)']

# %% [markdown]
# # Removing rows with all values missing and striping whitespaces

# %%
# Checking total number of rows with all cells empty
df.isnull().all(axis=1).sum()
# Out:
# 9

# %%
# Drop all the rows with all cells empty
df.dropna(how='all', inplace=True)

# %%
# Reseting the index of the dataframe
df.reset_index(drop = True, inplace = True)

# %%
# Remove trailing and leading whitespaces
df.loc[:,:] = df.applymap(lambda x: x.strip() if type(x)==str else x)

# %%
# Locate rows of duplicate data
dups = df.duplicated()
print(dups.any())
# Out:
# False

# %% [markdown]
# # Making a backup

# %%
''' In order to make a copy of the dataframe we need two different instances of the dataframe, if we don't do that any changes
made to any of the variables that reference to dataframe will modify the other one. In that case we use the method copy().'''
wildfire_df = df.copy()

# %% [markdown]
# # Arrange Numeric Columns

# %% [markdown]
# ### Preparing column 'Fire Size (Acres)'

# %%
# Copy values of acres in column 'Personnel Involved' that pertain to column 'Fire Size (Acres)'
wildfire_df = mt.emend_values(df, wildfire_df, 'Personnel Involved', 'Fire Size (Acres)', r'.*\s*Acres')

# %%
# Remove the string 'Acres' that comes along with the digits
wildfire_df = mt.strip_symbol(wildfire_df, 'Fire Size (Acres)', 'Acres')

# %%
# Convert the string digits to integer values
wildfire_df = mt.convert_to_int(wildfire_df, 'Fire Size (Acres)')

# %%
 # Check for value types 
wildfire_df['Fire Size (Acres)'].apply(type)
# Out:
# 0       <class 'int'>
# 1       <class 'int'>
# 2       <class 'int'>
# 3       <class 'int'>
# 4       <class 'int'>
# 5       <class 'int'>
# 6     <class 'float'>
# 7       <class 'int'>
# 8       <class 'int'>
# 9       <class 'int'>
# 10      <class 'int'>
# 11    <class 'float'>
# 12      <class 'int'>
# 13      <class 'int'>
# 14      <class 'int'>
# 15      <class 'int'>
# 16      <class 'int'>
# 17      <class 'int'>
# 18      <class 'int'>
# 19      <class 'int'>
# 20      <class 'int'>
# 21      <class 'int'>
# 22      <class 'int'>
# 23      <class 'int'>
# 24      <class 'int'>
# 25      <class 'int'>
# 26      <class 'int'>
# 27      <class 'int'>
# 28    <class 'float'>
# 29      <class 'int'>
# 30      <class 'int'>
# 31      <class 'int'>
# 32      <class 'int'>
# 33      <class 'int'>
# 34      <class 'int'>
# 35      <class 'int'>
# 36      <class 'int'>
# 37      <class 'int'>
# 38      <class 'int'>
# 39      <class 'int'>
# 40      <class 'int'>
# 41      <class 'int'>
# 42      <class 'int'>
# 43      <class 'int'>
# 44      <class 'int'>
# 45      <class 'int'>
# 46    <class 'float'>
# 47      <class 'int'>
# 48    <class 'float'>
# 49      <class 'int'>
# 50      <class 'int'>
# 51      <class 'int'>
# 52      <class 'int'>
# 53    <class 'float'>
# 54      <class 'int'>
# 55      <class 'int'>
# 56      <class 'int'>
# 57      <class 'int'>
# 58      <class 'int'>
# 59      <class 'int'>
# 60      <class 'int'>
# 61      <class 'int'>
# 62      <class 'int'>
# 63      <class 'int'>
# 64      <class 'int'>
# 65      <class 'int'>
# 66      <class 'int'>
# 67      <class 'int'>
# 68      <class 'int'>
# 69      <class 'int'>
# 70      <class 'int'>
# 71      <class 'int'>
# 72      <class 'int'>
# 73      <class 'int'>
# 74      <class 'int'>
# 75      <class 'int'>
# 76      <class 'int'>
# 77      <class 'int'>
# 78      <class 'int'>
# 79      <class 'int'>
# 80      <class 'int'>
# 81      <class 'int'>
# 82    <class 'float'>
# 83      <class 'int'>
# 84      <class 'int'>
# 85      <class 'int'>
# 86      <class 'int'>
# 87      <class 'int'>
# 88      <class 'int'>
# 89    <class 'float'>
# 90      <class 'int'>
# 91      <class 'int'>
# 92      <class 'int'>
# 93      <class 'int'>
# 94      <class 'int'>
# 95      <class 'int'>
# 96      <class 'int'>
# 97      <class 'int'>
# 98      <class 'int'>
# 99      <class 'int'>
# Name: Fire Size (Acres), dtype: object

# %% [markdown]
# ## Preparing column 'Perimeter Contained (%)'

# %%
# Get values in column 'Fire Size (Acres)' that belong to column 'Perimeter Contained (%)'
wildfire_df = mt.emend_values(df, wildfire_df, 'Fire Size (Acres)', 'Perimeter Contained (%)', r'^\d*[.]{0,1}\d*\s*%$')

# %%
# Get rid of '%' symbol
wildfire_df = mt.strip_symbol(wildfire_df, 'Perimeter Contained (%)', '%')

# %%
# Convert float values to integer
wildfire_df = mt.convert_to_int(wildfire_df, 'Perimeter Contained (%)')

# %%
# 
wildfire_df['Perimeter Contained (%)'].apply(type).value_counts()
# Out:
# <class 'int'>      82
# <class 'float'>    14
# <class 'str'>       4
# Name: Perimeter Contained (%), dtype: int64

# %%
# Convert string values to NaN
wildfire_df = mt.str_to_nan(wildfire_df, 'Perimeter Contained (%)')

# %%
wildfire_df['Perimeter Contained (%)'].apply(type).value_counts()
# Out:
# <class 'float'>    100
# Name: Perimeter Contained (%), dtype: int64

# %%
wildfire_df.loc[:, 'Personnel Involved']
# Out:
# 0        600 Acres
# 1              243
# 2         73 Acres
# 3              757
# 4               93
# 5               80
# 6              NaN
# 7      1,700 Acres
# 8          2 Acres
# 9               30
# 10              38
# 11             NaN
# 12              20
# 13              25
# 14           1,563
# 15               3
# 16             249
# 17              90
# 18              25
# 19    24,729 Acres
# 20               5
# 21              20
# 22             132
# 23        42 Acres
# 24             168
# 25              11
# 26              10
# 27             177
# 28             NaN
# 29             288
# 30              19
# 31             309
# 32              79
# 33              16
# 34               1
# 35             304
# 36             185
# 37               3
# 38              16
# 39               1
# 40             150
# 41             272
# 42       180 Acres
# 43    71,450 Acres
# 44               3
# 45               4
# 46             NaN
# 47    23,142 Acres
# 48             NaN
# 49             134
# 50             193
# 51             215
# 52    14,624 Acres
# 53             NaN
# 54             255
# 55              44
# 56              30
# 57              71
# 58              67
# 59              96
# 60              18
# 61         2 Acres
# 62             142
# 63              58
# 64              30
# 65             201
# 66        15 Acres
# 67         1 Acres
# 68             134
# 69               9
# 70             115
# 71             233
# 72               5
# 73               5
# 74              32
# 75              18
# 76        81 Acres
# 77             149
# 78              22
# 79       478 Acres
# 80               3
# 81        70 Acres
# 82             NaN
# 83             120
# 84             751
# 85        67 Acres
# 86       104 Acres
# 87             102
# 88             345
# 89             NaN
# 90        25 Acres
# 91             101
# 92             553
# 93              92
# 94             318
# 95             319
# 96           1,490
# 97              40
# 98             143
# 99             897
# Name: Personnel Involved, dtype: object

# %%
wildfire_df[['Personnel Involved','Perimeter Contained (%)']].applymap(type)
# Out:
#    Personnel Involved Perimeter Contained (%)
# 0       <class 'str'>         <class 'float'>
# 1       <class 'str'>         <class 'float'>
# 2       <class 'str'>         <class 'float'>
# 3       <class 'str'>         <class 'float'>
# 4       <class 'str'>         <class 'float'>
# 5       <class 'str'>         <class 'float'>
# 90      <class 'str'>
# 91      <class 'str'>
# 92      <class 'str'>
# 93      <class 'str'>
# 94      <class 'str'>
# 95      <class 'str'>
# 96      <class 'str'>
# 97      <class 'str'>
# 98      <class 'str'>
# 99      <class 'str'>
# Name: Personnel Involved, dtype: object

# %%
wildfire_df['Personnel Involved'].apply(type).value_counts()
# Out:
# <class 'str'>      92
# <class 'float'>     8
# Name: Personnel Involved, dtype: int64

# %%
wildfire_df['Personnel Involved'].isnull().sum()
# Out:
# 8

# %%
wildfire_df = mt.convert_to_int(wildfire_df, 'Personnel Involved')

# %%
wildfire_df = mt.str_to_nan(wildfire_df, 'Personnel Involved')

# %%
wildfire_df.loc[:,'Personnel Involved'].head(100)
# Out:
# 0     <NA>
# 1      243
# 2     <NA>
# 3      757
# 4       93
# 5       80
# 6     <NA>
# 7     <NA>
# 8     <NA>
# 9       30
# 10      38
# 11    <NA>
# 12      20
# 13      25
# 14    1563
# 15       3
# 16     249
# 17      90
# 18      25
# 19    <NA>
# 20       5
# 21      20
# 22     132
# 23    <NA>
# 24     168
# 25      11
# 26      10
# 27     177
# 28    <NA>
# 29     288
# 30      19
# 31     309
# 32      79
# 33      16
# 34       1
# 35     304
# 36     185
# 37       3
# 38      16
# 39       1
# 40     150
# 41     272
# 42    <NA>
# 43    <NA>
# 44       3
# 45       4
# 46    <NA>
# 47    <NA>
# 48    <NA>
# 49     134
# 50     193
# 51     215
# 52    <NA>
# 53    <NA>
# 54     255
# 55      44
# 56      30
# 57      71
# 58      67
# 59      96
# 60      18
# 61    <NA>
# 62     142
# 63      58
# 64      30
# 65     201
# 66    <NA>
# 67    <NA>
# 68     134
# 69       9
# 70     115
# 71     233
# 72       5
# 73       5
# 74      32
# 75      18
# 76    <NA>
# 77     149
# 78      22
# 79    <NA>
# 80       3
# 81    <NA>
# 82    <NA>
# 83     120
# 84     751
# 85    <NA>
# 86    <NA>
# 87     102
# 88     345
# 89    <NA>
# 90    <NA>
# 91     101
# 92     553
# 93      92
# 94     318
# 95     319
# 96    1490
# 97      40
# 98     143
# 99     897
# Name: Personnel Involved, dtype: Int16

# %%
wildfire_df = mt.convert_to_string(wildfire_df, 'Personnel Involved')

# %%
wildfire_df['Personnel Involved'] = wildfire_df['Personnel Involved'] .astype('Int64')

# %%
wildfire_df[['Fire Size (Acres)','Personnel Involved','Perimeter Contained (%)']].applymap(type)
# Out:
#    Fire Size (Acres)                     Personnel Involved  \
# 0      <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 1      <class 'int'>                          <class 'int'>
# 2      <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 3      <class 'int'>                          <class 'int'>
# 4      <class 'int'>                          <class 'int'>
# 5      <class 'int'>                          <class 'int'>
# 6    <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 7      <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 8      <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 9      <class 'int'>                          <class 'int'>
# 10     <class 'int'>                          <class 'int'>
# 11   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 12     <class 'int'>                          <class 'int'>
# 13     <class 'int'>                          <class 'int'>
# 14     <class 'int'>                          <class 'int'>
# 15     <class 'int'>                          <class 'int'>
# 16     <class 'int'>                          <class 'int'>
# 17     <class 'int'>                          <class 'int'>
# 18     <class 'int'>                          <class 'int'>
# 19     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 20     <class 'int'>                          <class 'int'>
# 21     <class 'int'>                          <class 'int'>
# 22     <class 'int'>                          <class 'int'>
# 23     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 24     <class 'int'>                          <class 'int'>
# 25     <class 'int'>                          <class 'int'>
# 26     <class 'int'>                          <class 'int'>
# 27     <class 'int'>                          <class 'int'>
# 28   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 29     <class 'int'>                          <class 'int'>
# 30     <class 'int'>                          <class 'int'>
# 31     <class 'int'>                          <class 'int'>
# 32     <class 'int'>                          <class 'int'>
# 33     <class 'int'>                          <class 'int'>
# 34     <class 'int'>                          <class 'int'>
# 35     <class 'int'>                          <class 'int'>
# 36     <class 'int'>                          <class 'int'>
# 37     <class 'int'>                          <class 'int'>
# 38     <class 'int'>                          <class 'int'>
# 39     <class 'int'>                          <class 'int'>
# 40     <class 'int'>                          <class 'int'>
# 41     <class 'int'>                          <class 'int'>
# 42     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 43     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 44     <class 'int'>                          <class 'int'>
# 45     <class 'int'>                          <class 'int'>
# 46   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 47     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 48   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 49     <class 'int'>                          <class 'int'>
# 50     <class 'int'>                          <class 'int'>
# 51     <class 'int'>                          <class 'int'>
# 52     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 53   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 54     <class 'int'>                          <class 'int'>
# 55     <class 'int'>                          <class 'int'>
# 56     <class 'int'>                          <class 'int'>
# 57     <class 'int'>                          <class 'int'>
# 58     <class 'int'>                          <class 'int'>
# 59     <class 'int'>                          <class 'int'>
# 60     <class 'int'>                          <class 'int'>
# 61     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 62     <class 'int'>                          <class 'int'>
# 63     <class 'int'>                          <class 'int'>
# 64     <class 'int'>                          <class 'int'>
# 65     <class 'int'>                          <class 'int'>
# 66     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 67     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 68     <class 'int'>                          <class 'int'>
# 69     <class 'int'>                          <class 'int'>
# 70     <class 'int'>                          <class 'int'>
# 71     <class 'int'>                          <class 'int'>
# 72     <class 'int'>                          <class 'int'>
# 73     <class 'int'>                          <class 'int'>
# 74     <class 'int'>                          <class 'int'>
# 75     <class 'int'>                          <class 'int'>
# 76     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 77     <class 'int'>                          <class 'int'>
# 78     <class 'int'>                          <class 'int'>
# 79     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 80     <class 'int'>                          <class 'int'>
# 81     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 82   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 83     <class 'int'>                          <class 'int'>
# 84     <class 'int'>                          <class 'int'>
# 85     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 86     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 87     <class 'int'>                          <class 'int'>
# 88     <class 'int'>                          <class 'int'>
# 89   <class 'float'>  <class 'pandas._libs.missing.NAType'>
# 90     <class 'int'>  <class 'pandas._libs.missing.NAType'>
# 91     <class 'int'>                          <class 'int'>
# 92     <class 'int'>                          <class 'int'>
# 93     <class 'int'>                          <class 'int'>
# 94     <class 'int'>                          <class 'int'>
# 95     <class 'int'>                          <class 'int'>
# 96     <class 'int'>                          <class 'int'>
# 97     <class 'int'>                          <class 'int'>
# 98     <class 'int'>                          <class 'int'>
# 99     <class 'int'>                          <class 'int'>
#
#    Perimeter Contained (%)
# 0          <class 'float'>
# 1          <class 'float'>
# 2          <class 'float'>
# 3          <class 'float'>
# 4          <class 'float'>
# 5          <class 'float'>
# 6          <class 'float'>
# 7          <class 'float'>
# 8          <class 'float'>
# 9          <class 'float'>
# 10         <class 'float'>
# 11         <class 'float'>
# 12         <class 'float'>
# 13         <class 'float'>
# 14         <class 'float'>
# 15         <class 'float'>
# 16         <class 'float'>
# 17         <class 'float'>
# 18         <class 'float'>
# 19         <class 'float'>
# 20         <class 'float'>
# 21         <class 'float'>
# 22         <class 'float'>
# 23         <class 'float'>
# 24         <class 'float'>
# 25         <class 'float'>
# 26         <class 'float'>
# 27         <class 'float'>
# 28         <class 'float'>
# 29         <class 'float'>
# 30         <class 'float'>
# 31         <class 'float'>
# 32         <class 'float'>
# 33         <class 'float'>
# 34         <class 'float'>
# 35         <class 'float'>
# 36         <class 'float'>
# 37         <class 'float'>
# 38         <class 'float'>
# 39         <class 'float'>
# 40         <class 'float'>
# 41         <class 'float'>
# 42         <class 'float'>
# 43         <class 'float'>
# 44         <class 'float'>
# 45         <class 'float'>
# 46         <class 'float'>
# 47         <class 'float'>
# 48         <class 'float'>
# 49         <class 'float'>
# 50         <class 'float'>
# 51         <class 'float'>
# 52         <class 'float'>
# 53         <class 'float'>
# 54         <class 'float'>
# 55         <class 'float'>
# 56         <class 'float'>
# 57         <class 'float'>
# 58         <class 'float'>
# 59         <class 'float'>
# 60         <class 'float'>
# 61         <class 'float'>
# 62         <class 'float'>
# 63         <class 'float'>
# 64         <class 'float'>
# 65         <class 'float'>
# 66         <class 'float'>
# 67         <class 'float'>
# 68         <class 'float'>
# 69         <class 'float'>
# 70         <class 'float'>
# 71         <class 'float'>
# 72         <class 'float'>
# 73         <class 'float'>
# 74         <class 'float'>
# 75         <class 'float'>
# 76         <class 'float'>
# 77         <class 'float'>
# 78         <class 'float'>
# 79         <class 'float'>
# 80         <class 'float'>
# 81         <class 'float'>
# 82         <class 'float'>
# 83         <class 'float'>
# 84         <class 'float'>
# 85         <class 'float'>
# 86         <class 'float'>
# 87         <class 'float'>
# 88         <class 'float'>
# 89         <class 'float'>
# 90         <class 'float'>
# 91         <class 'float'>
# 92         <class 'float'>
# 93         <class 'float'>
# 94         <class 'float'>
# 95         <class 'float'>
# 96         <class 'float'>
# 97         <class 'float'>
# 98         <class 'float'>
# 99         <class 'float'>

# %%
# To finalize the numeric columns preparation we save the dataframe as a csv file
wildfire_df.to_csv('blazes/fires_v2.csv', index = False)

# %%
wildf[['Fire Size (Acres)','Personnel Involved','Perimeter Contained (%)']].applymap(type)
# Out:
#    Fire Size (Acres) Personnel Involved Perimeter Contained (%)
# 0    <class 'float'>    <class 'float'>         <class 'float'>
# 1    <class 'float'>    <class 'float'>         <class 'float'>
# 2    <class 'float'>    <class 'float'>         <class 'float'>
# 3    <class 'float'>    <class 'float'>         <class 'float'>
# 4    <class 'float'>    <class 'float'>         <class 'float'>
# 5    <class 'float'>    <class 'float'>         <class 'float'>
# 6    <class 'float'>    <class 'float'>         <class 'float'>
# 7    <class 'float'>    <class 'float'>         <class 'float'>
# 8    <class 'float'>    <class 'float'>         <class 'float'>
# 9    <class 'float'>    <class 'float'>         <class 'float'>
# 10   <class 'float'>    <class 'float'>         <class 'float'>
# 11   <class 'float'>    <class 'float'>         <class 'float'>
# 12   <class 'float'>    <class 'float'>         <class 'float'>
# 13   <class 'float'>    <class 'float'>         <class 'float'>
# 14   <class 'float'>    <class 'float'>         <class 'float'>
# 15   <class 'float'>    <class 'float'>         <class 'float'>
# 16   <class 'float'>    <class 'float'>         <class 'float'>
# 17   <class 'float'>    <class 'float'>         <class 'float'>
# 18   <class 'float'>    <class 'float'>         <class 'float'>
# 19   <class 'float'>    <class 'float'>         <class 'float'>
# 20   <class 'float'>    <class 'float'>         <class 'float'>
# 21   <class 'float'>    <class 'float'>         <class 'float'>
# 22   <class 'float'>    <class 'float'>         <class 'float'>
# 23   <class 'float'>    <class 'float'>         <class 'float'>
# 24   <class 'float'>    <class 'float'>         <class 'float'>
# 25   <class 'float'>    <class 'float'>         <class 'float'>
# 26   <class 'float'>    <class 'float'>         <class 'float'>
# 27   <class 'float'>    <class 'float'>         <class 'float'>
# 28   <class 'float'>    <class 'float'>         <class 'float'>
# 29   <class 'float'>    <class 'float'>         <class 'float'>
# 30   <class 'float'>    <class 'float'>         <class 'float'>
# 31   <class 'float'>    <class 'float'>         <class 'float'>
# 32   <class 'float'>    <class 'float'>         <class 'float'>
# 33   <class 'float'>    <class 'float'>         <class 'float'>
# 34   <class 'float'>    <class 'float'>         <class 'float'>
# 35   <class 'float'>    <class 'float'>         <class 'float'>
# 36   <class 'float'>    <class 'float'>         <class 'float'>
# 37   <class 'float'>    <class 'float'>         <class 'float'>
# 38   <class 'float'>    <class 'float'>         <class 'float'>
# 39   <class 'float'>    <class 'float'>         <class 'float'>
# 94   <class 'float'>    <class 'float'>         <class 'float'>
# 95   <class 'float'>    <class 'float'>         <class 'float'>
# 96   <class 'float'>    <class 'float'>         <class 'float'>
# 97   <class 'float'>    <class 'float'>         <class 'float'>
# 98   <class 'float'>    <class 'float'>         <class 'float'>
# 99   <class 'float'>    <class 'float'>         <class 'float'>

# %%
wildf.head()
# Out:
#                                            Cause  \
# 0  Saturday August 15th, 2020 approx.   07:15 AM
# 1                                      Lightning
# 2                                      Powerline
# 3                                      Lightning
# 4                                        Unknown
#
#                            Coordinates  \
# 0                                  NaN
# 1   33.544 latitude, -110.42 longitude
# 2  30.863 latitude, -100.548 longitude
# 3                             Wildfire
# 4                             Wildfire
#
#                                             Date  \
# 0          Tyler Brown, Texas A&M Forest Service
# 1  Saturday August 01st, 2020 approx.   04:30 PM
# 2  Thursday August 13th, 2020 approx.   03:15 PM
# 3      Friday July 31st, 2020 approx.   05:15 PM
# 4    Friday August 14th, 2020 approx.   11:43 AM
#
#                                                                                                                                                                                                 Fuels Involved  \
# 0                                                                                                                                                                                                          NaN
# 1  Primary carrier of the fire is currently the timber litter, grass and light brush associated with the under story of the ponderosa pine forest. Oak scrub is involved on the western edge of the burn area.
# 2                                                                                                                                                                                                          NaN
# 3                                                                                                                                                                               Pinyon, juniper, oak, and sage
# 4                                                                                                                                                                                 Timber,litter and understory
#
#                  Incident Incident Type  \
# 0            Chimney Fire      Wildfire
# 1  Cassadore Springs Fire      Wildfire
# 2           Bucholtz Fire      Wildfire
# 3         Pine Gulch Fire      Wildfire
# 4           Williams Fork      Wildfire
#
#                                      Location  Perimeter Contained (%)  \
# 0          32.722 latitude, -99.481 longitude                     40.0
# 1            11 miles north of San Carlos, AZ                     90.0
# 2                    5 miles east of Eldorado                    100.0
# 3  18 miles north of Grand Junction, Colorado                      7.0
# 4                   15 miles NW of Fraser, CO                      NaN
#
#    Personnel Involved  Fire Size (Acres)
# 0                 NaN              600.0
# 1               243.0            21284.0
# 2                 NaN               73.0
# 3               757.0            74807.0
# 4                93.0             1300.0

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.6.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 7
# machine          : AMD64
# processor        : Intel64 Family 6 Model 60 Stepping 3, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 1.0.1
# numpy            : 1.19.1
# pytz             : 2019.3
# dateutil         : 2.8.1
# pip              : 20.2.2
# setuptools       : 45.2.0.post20200210
# Cython           : 0.29.15
# pytest           : 5.3.5
# hypothesis       : 5.5.4
# sphinx           : 2.4.0
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.7
# lxml.etree       : 4.5.0
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.1
# IPython          : 7.12.0
# pandas_datareader: 0.9.0
# bs4              : 4.8.2
# bottleneck       : 1.3.2
# fastparquet      : None
# gcsfs            : None
# lxml.etree       : 4.5.0
# matplotlib       : 3.1.3
# numexpr          : 2.7.1
# odfpy            : None
# openpyxl         : 3.0.3
# pandas_gbq       : None
# pyarrow          : None
# pytables         : None
# pytest           : 5.3.5
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.4.1
# sqlalchemy       : 1.3.13
# tables           : 3.6.1
# tabulate         : None
# xarray           : None
# xlrd             : 1.2.0
# xlwt             : 1.3.0
# xlsxwriter       : 1.2.7
# numba            : 0.48.0

# %% [markdown]
# # Arrange Categorical Columns

# %% [markdown]
# ## Preparing Column 'Coordinates'

# %%
# Read the csv file into a new dataframe
wildf = pd.read_csv('blazes/fires_v2.csv')

# %%
# Make a copy of the dataframe
wildf_dfv2 = wildf.copy()

# %%
# Copy the values from column 'Location' to the corresponding cells in column 'Coordinates'
wildf_dfv2 = mt.emend_values(df, wildf_dfv2, 'Location', 'Coordinates', r'-?\d+\.?\d+\s*latitude,?\s*-?\d+\.?\d+\s*longitude')

# %%
# Copy the values from column 'Cause' to the corresponding cells in column 'Coordinates'
wildf_dfv2 = mt.emend_values(df, wildf_dfv2, 'Cause', 'Coordinates', r'-?\d+\.?\d+\s*latitude,?\s*-?\d+\.?\d+\s*longitude')

# %%
# Create a new column 'Latitude' with the values that go along with 'latitude' in column 'Coordinates'
wildf_dfv2 = mt.create_new_col(wildf_dfv2, r'-?\d+\.?\d+\s*(?=latitude)', 'Coordinates', 'Latitude')

# %%
# Create a new column 'Longitude' with the values that go along with 'longitude' in column 'Coordinates'
wildf_dfv2 = mt.create_new_col(wildf_dfv2, r'-?\d+\.?\d+\s*(?=longitude)', 'Coordinates', 'Longitude')

# %%
# Show value types totals
wildf_dfv2['Latitude'].apply(type).value_counts()
# Out:
# <class 'str'>    100
# Name: Latitude, dtype: int64

# %%
# Show empty strings totals
(wildf_dfv2['Latitude'] == '').sum()
# Out:
# 37

# %%
# Fill empty strings with NaNs values in column 'Longitude'
wildf_dfv2['Longitude'].replace(r'^\s*$', np.nan, regex=True, inplace = True)

# %%
# Fill empty strings with NaNs values in column 'Latitude'
wildf_dfv2['Latitude'].replace(r'^\s*$', np.nan, regex=True, inplace = True)

# %%
# Show value types totals
wildf_dfv2['Latitude'].apply(type).value_counts()
# Out:
# <class 'str'>      63
# <class 'float'>    37
# Name: Latitude, dtype: int64

# %%
# Show null values totals
wildf_dfv2['Latitude'].isnull().sum()
# Out:
# 37

# %%
# Convert strings to float in column 'Latitude'
wildf_dfv2['Latitude'] = pd.to_numeric(wildf_dfv2['Latitude'], downcast='float')

# %%
# Convert strings to float in column 'Longitude'
wildf_dfv2['Longitude'] = pd.to_numeric(wildf_dfv2['Longitude'], downcast='float')

# %%
# Drop column 'Coordinates'
wildf_dfv2.drop(['Coordinates'], axis=1, inplace=True)

# %% [markdown]
# ## Preparing Column 'Date'

# %%
# Copy the values from column 'Cause' to the corresponding cells in column 'Date'
wildf_dfv2 = mt.emend_values(df, wildf_dfv2, 'Cause', 'Date', r'(\d{2}:\d{2}\s?(AM|PM))$')

# %%
# Remove string 'approx.' from the string containing the day and hour
wildf_dfv2 = mt.strip_symbol(wildf_dfv2, 'Date', 'approx.')

# %%
# Convert date entries from 'Date' column to ISO format
wildf_dfv2 = mt.convert_to_isodate(wildf_dfv2, 'Date')

# %%
# Drop column 'Date'
wildf_dfv2.drop(['Date'], axis=1, inplace=True)

# %%
#wildf_dfv2.loc[:,['Date', 'ISO Date']].head()

# %% [markdown]
# ## Preparing Column 'Cause'

# %%
# Get rid of strings of dates
wildf_dfv2 = mt.strip_string(wildf_dfv2, 'Cause', r'-?\d+\.?\d+\s*latitude,?\s*-?\d+\.?\d+\s*longitude')

# %%
# Get rid of strings of coordinates
wildf_dfv2 = mt.strip_string(wildf_dfv2, 'Cause', r'(\d{2}:\d{2}\s?(AM|PM))$')

# %%
# Remove trailing and leading whitespaces
wildf_dfv2.loc[:, 'Cause'] = wildf_dfv2.loc[:, 'Cause'].apply(lambda x: x.strip() if type(x)==str else x)

# %%
# Replace empty strings with NaN values
wildf_dfv2['Cause'].replace(r'^\s*$', np.nan, regex=True, inplace = True)

# %%
# Create and populate set with causes of fire
causes = set()
for item in wildf_dfv2['Cause']:
    if isinstance(item, str):
        if item not in causes:
            causes.add(item)
print(causes)
# Out:
# {'Lightning', 'Piece From Faulty Catalytic Converter', 'Human Caused', 'Accidental Roadside Start', 'Unknown, Under Investigation', 'Human-caused - Suspected Arson', 'Debris Burning', 'Human', 'Lightning/natural', 'Natural, Lightning', 'Powerline', 'Unknown', 'Human-caused', 'Human Caused, Under Investigation', 'Under Investigation', 'Unkown'}

# %%
# List causes of fire from set 'causes'
i=1
for item in causes:
    print(i,'->',item)
    i += 1
# Out:
# 1 -> Lightning
# 2 -> Piece From Faulty Catalytic Converter
# 3 -> Human Caused
# 4 -> Accidental Roadside Start
# 5 -> Unknown, Under Investigation
# 6 -> Human-caused - Suspected Arson
# 7 -> Debris Burning
# 8 -> Human
# 9 -> Lightning/natural
# 10 -> Natural, Lightning
# 11 -> Powerline
# 12 -> Unknown
# 13 -> Human-caused
# 14 -> Human Caused, Under Investigation
# 15 -> Under Investigation
# 16 -> Unkown

# %%
# Ad hoc function for replacing and fixing redundant values in column 'Cause'
result = ""
def is_match(pattern, x, word):
    global result
    if isinstance(x, str):
        match = re.search(pattern, x)
        if match:
            result = x.replace(match.string, word)
        else:
            return False
    else:
        return False
    return True

# %%
# Using function 'is_match' with a lambda function
wildf_dfv2.loc[:, 'Cause'] = wildf_dfv2.loc\
[:, 'Cause'].apply(lambda x:x.replace(x, result) if\
is_match(r'Lightning', x, 'Lightning') else x)

# %%
# Using function 'is_match' with a lambda function
wildf_dfv2.loc[:, 'Cause'] = wildf_dfv2.loc\
[:, 'Cause'].apply(lambda x:x.replace(x, result)\
if is_match(r'Human', x, 'Human Caused') else x)

# %%
# Using function 'is_match' with a lambda function
wildf_dfv2.loc[:, 'Cause'] = wildf_dfv2.loc\
[:, 'Cause'].apply(lambda x:x.replace(x, result)\
                   if is_match(r'Unk[n]?own', x, 'Unknown') else x)

# %%
wildf_dfv2.loc[:, 'Cause'].head()
# Out:
# 0          NaN
# 1    Lightning
# 2    Powerline
# 3    Lightning
# 4      Unknown
# Name: Cause, dtype: object

# %% [markdown]
# ## Creating column Region

# %%
# Get the location given by latitude and longitude coordinates
def get_location(coordinates):
    return rg.search(coordinates)

# %%
# Function for creating column 'Region' based on coordinates data
def create_region_col(df):
    i = 0
    for latitude, longitude in zip(wildf_dfv2['Latitude'], wildf_dfv2['Longitude']):        
        if (not math.isnan(latitude) and not math.isnan(longitude)):
           coordinates = (latitude, longitude)
           location = get_location(coordinates)
           df.at[i, 'Region'] = list(location[0].values())[3]
           i += 1            
        else:
           i += 1

# %%
# Call to function create_region_col
create_region_col(wildf_dfv2)

# %%
# Checking null values after last call to create_region_col
wildf_dfv2.loc[:,  'Region'].isnull().sum()
# Out:
# 37

# %%
wildf_dfv2.loc[15:24, ['Location', 'Latitude', 'Longitude', 'Region']]
# Out:
#                                               Location   Latitude   Longitude  \
# 15                          25 miles west of Cody, Wyo  44.459000 -109.546997
# 16               17 miles southwest of Stevens Village  65.853996 -149.578995
# 17                                Darrell Willis, DFFM  33.806999 -112.119003
# 18                                     NE of New River        NaN         NaN
# 19                              Superstition Mountains  33.418999 -111.301003
# 20                                      Split Mountain        NaN         NaN
# 21  Up to 38 miles northeast of Mesa, AZ along Hwy 87.        NaN         NaN
# 22                       East side of Peavine Mountain  39.576000 -119.913002
# 23                                23 miles from Cortez        NaN         NaN
# 24                     5 miles north of Oak City, Utah        NaN         NaN
#
#       Region
# 15   Wyoming
# 16    Alaska
# 17   Arizona
# 18  Nebraska
# 19   Arizona
# 20       NaN
# 21   Arizona
# 22    Nevada
# 23       NaN
# 24      Utah

# %% [markdown]
# ## Appendix Section

# %%
wildf_dfv21 = wildf_dfv2.copy()

# %%
wildf_dfv21['Region'].isnull().sum()
# Out:
# 15

# %%
# Dictionary with US states names and their abbrevations
us_abbrev_dic={'Alabama': 'AL', 'Alaska': 'AK', 'Arizona':'AZ', 'Arkansas':'AR',
               'California': 'CA', 'Colorado':'CO', 'Connecticut':'CT', 'Delaware':'DE',
               'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID',
               'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS',
               'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
               'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
               'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV',
               'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY',
               'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
               'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
               'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT',
               'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV',
               'Wisconsin': 'WI', 'Wyoming': 'WY'  
              }
st = us_abbrev_dic

# %%
# Ad hoc function for completing states names in column 'Region' based on column 'Location' data
def foo2(df, col):
    i=0
    flag=0
    list_count = 0
    wordup = ''
    for sentence in df[col]:
        if not isinstance(df.at[i,'Region'], str):
            if isinstance(sentence, str):
                word_list = re.findall(r'\w+', sentence)
                word_list_len = len(word_list)
                for word in word_list:
                    list_count += 1
                    if len(word)>2:
                        wordup = word.upper()
                    else:
                        wordup = word
                    for st_name, st_abbrev in st.items():
                        upper_st = st_name.upper()
                        if (wordup == upper_st or wordup == st_abbrev):
                            df.at[i,'Region'] = st_name
                            i+=1
                            flag = 1
                            break
                    if (list_count == word_list_len and flag ==0):
                        list_count = 0
                        i+=1
                    elif(flag == 1):
                        list_count = 0
                        flag = 0
                        break
            else:
                i+=1
        else:
            i+=1

# %%
# Call to function foo2
foo2(wildf_dfv21, 'Location')

# %%
# Listing the rows of 'Location' that will be googled
i = 0
indexes = list()
for item, name in zip(wildf_dfv21['Region'], wildf_dfv21['Location']):
    if (isinstance(item, float) and not isinstance(name, float)):
        indexes.append(wildf_dfv21.index[wildf_dfv21['Location'] == name].tolist())
        print(indexes[i][0], '->', name)
        i += 1
# Out:
# 12 -> Ryan Carbajal
# 40 -> Wildland Fire

# %%
# Dictionary with the last states with keys serving as dataframe corresponding indexes
last_st = {20:'California', 23:'Colorado', 26: 'Arizona', 33: 'Arizona',\
          53: 'Oregon', 56: 'Arizona', 61: 'Idaho', 67: 'Nevada', 76: 'California',\
           78: 'California', 97: 'Arizona', 98: 'California'}

# %%
# Set last missing states
for key, values in last_st.items():
        wildf_dfv21.at[key, 'Region'] = values

# %%
wildf_dfv21.loc[[12,40], ['Incident', 'Location', 'Region']].head(41)
# Out:
#        Incident       Location Region
# 12         Seco  Ryan Carbajal    NaN
# 40  Milepost 21  Wildland Fire    NaN

# %%
wildf_dfv21.at[12, 'Region'] = 'New Mexico'
wildf_dfv21.at[40, 'Region'] ='California'

# %%
# Drop column 'Location'
wildf_dfv21.drop(['Location'], axis=1, inplace=True)

# %%
# Drop column 'Incident'
wildf_dfv21.drop(['Incident'], axis=1, inplace=True)

# %%
# Save dataframe to csv file
wildf_dfv21.to_csv('blazes/fires_v3.csv', index = False)

# %% [markdown]
# ## Final Tweakings

# %%
# Read the csv file into a new dataframe
wildf = pd.read_csv('blazes/fires_v3.csv')

# %%
# Make a copy
wildf_dfv3 = wildf.copy()

# %%
# Show selected columns where column 'Incident Type' is 'Burned Area Emergency Response'
exclude = ['Latitude','Longitude', 'Fuels Involved', 'Region']
wildf_dfv3.loc[wildf_dfv3['Incident Type'] == 'Burned Area Emergency Response', wildf_dfv3.columns.difference(exclude, sort=False)]
# Out:
#    Cause                   Incident Type  Perimeter Contained (%)  \
# 11   NaN  Burned Area Emergency Response                      NaN
# 28   NaN  Burned Area Emergency Response                      NaN
# 46   NaN  Burned Area Emergency Response                      NaN
#
#     Personnel Involved  Fire Size (Acres) ISO Date
# 11                 NaN                NaN      NaN
# 28                 NaN                NaN      NaN
# 46                 NaN                NaN      NaN

# %%
wildf_dfv3.drop(index=wildf_dfv3[wildf_dfv3['Incident Type'] == 'Burned Area Emergency Response'].index, inplace=True)

# %%
# Checking total number of rows with all cells empty
wildf_dfv3.isnull().all(axis=1).sum()

# %%
# Drop all the rows with all cells empty
wildf_dfv3.dropna(how='all', inplace=True)

# %%
wildf_dfv3.shape
# Out:
# (96, 10)

# %%
# Converting float values to integers. When saving dataframe to csv int values are saved as float
wildf_dfv3[['Perimeter Contained (%)','Personnel Involved','Fire Size (Acres)']] = wildf_dfv3[['Perimeter Contained (%)','Personnel Involved','Fire Size (Acres)']].astype('Int64')

# %%
exclude = ['Latitude','Longitude', 'Fuels Involved']
wildf_dfv3.loc[:, wildf_dfv3.columns.difference(exclude, sort=False)].head(10)
# Out:
#         Cause Incident Type  Perimeter Contained (%)  Personnel Involved  \
# 0         NaN      Wildfire                       40                <NA>
# 1   Lightning      Wildfire                       90                 243
# 2   Powerline      Wildfire                      100                <NA>
# 3   Lightning      Wildfire                        7                 757
# 4     Unknown      Wildfire                     <NA>                  93
# 5   Lightning      Wildfire                       30                  80
# 7     Unknown      Wildfire                       90                <NA>
# 8         NaN      Wildfire                      100                <NA>
# 9     Unknown      Wildfire                       75                  30
# 10        NaN      Wildfire                       40                  38
#
#     Fire Size (Acres)             ISO Date    Region
# 0                 600  2020-08-15T07:15:00     Texas
# 1               21284  2020-08-01T16:30:00   Arizona
# 2                  73  2020-08-13T15:15:00     Texas
# 3               74807  2020-07-31T17:15:00  Colorado
# 4                1300  2020-08-14T11:43:00  Colorado
# 5                2900  2020-08-10T13:45:00   Arizona
# 7                1700                  NaN   Wyoming
# 8                   2  2020-08-15T12:15:00     Texas
# 9                   5  2020-08-06T00:00:00   Montana
# 10                770  2020-08-11T00:00:00   Wyoming

# %%
wildf_dfv3.to_csv('blazes/fires_v4.csv', index = False)

# %% [markdown]
# # This section is for analyzing the data

# %%
wildf_dfv21[['Fire Size (Acres)','Personnel Involved','Perimeter Contained (%)']].applymap(type)
# Out:
#    Fire Size (Acres) Personnel Involved Perimeter Contained (%)
# 0    <class 'float'>    <class 'float'>         <class 'float'>
# 1    <class 'float'>    <class 'float'>         <class 'float'>
# 2    <class 'float'>    <class 'float'>         <class 'float'>
# 3    <class 'float'>    <class 'float'>         <class 'float'>
# 4    <class 'float'>    <class 'float'>         <class 'float'>
# 5    <class 'float'>    <class 'float'>         <class 'float'>
# 6    <class 'float'>    <class 'float'>         <class 'float'>
# 7    <class 'float'>    <class 'float'>         <class 'float'>
# 8    <class 'float'>    <class 'float'>         <class 'float'>
# 9    <class 'float'>    <class 'float'>         <class 'float'>
# 10   <class 'float'>    <class 'float'>         <class 'float'>
# 11   <class 'float'>    <class 'float'>         <class 'float'>
# 12   <class 'float'>    <class 'float'>         <class 'float'>
# 67   <class 'float'>    <class 'float'>         <class 'float'>
# 68   <class 'float'>    <class 'float'>         <class 'float'>
# 69   <class 'float'>    <class 'float'>         <class 'float'>
# 70   <class 'float'>    <class 'float'>         <class 'float'>
# 71   <class 'float'>    <class 'float'>         <class 'float'>
# 72   <class 'float'>    <class 'float'>         <class 'float'>
# 73   <class 'float'>    <class 'float'>         <class 'float'>
# 74   <class 'float'>    <class 'float'>         <class 'float'>
# 75   <class 'float'>    <class 'float'>         <class 'float'>
# 76   <class 'float'>    <class 'float'>         <class 'float'>
# 77   <class 'float'>    <class 'float'>         <class 'float'>
# 78   <class 'float'>    <class 'float'>         <class 'float'>
# 79   <class 'float'>    <class 'float'>         <class 'float'>
# 80   <class 'float'>    <class 'float'>         <class 'float'>
# 81   <class 'float'>    <class 'float'>         <class 'float'>
# 82   <class 'float'>    <class 'float'>         <class 'float'>
# 83   <class 'float'>    <class 'float'>         <class 'float'>
# 84   <class 'float'>    <class 'float'>         <class 'float'>
# 85   <class 'float'>    <class 'float'>         <class 'float'>
# 86   <class 'float'>    <class 'float'>         <class 'float'>
# 87   <class 'float'>    <class 'float'>         <class 'float'>
# 88   <class 'float'>    <class 'float'>         <class 'float'>
# 89   <class 'float'>    <class 'float'>         <class 'float'>
# 90   <class 'float'>    <class 'float'>         <class 'float'>
# 91   <class 'float'>    <class 'float'>         <class 'float'>
# 92   <class 'float'>    <class 'float'>         <class 'float'>
# 93   <class 'float'>    <class 'float'>         <class 'float'>
# 94   <class 'float'>    <class 'float'>         <class 'float'>
# 95   <class 'float'>    <class 'float'>         <class 'float'>
# 96   <class 'float'>    <class 'float'>         <class 'float'>
# 97   <class 'float'>    <class 'float'>         <class 'float'>
# 98   <class 'float'>    <class 'float'>         <class 'float'>
# 99   <class 'float'>    <class 'float'>         <class 'float'>

# %%
us_capital_dic={
    'Alabama': 'Montgomery',
    'Alaska': 'Juneau',
    'Arizona':'Phoenix',
    'Arkansas':'Little Rock',
    'California': 'Sacramento',
    'Colorado':'Denver',
    'Connecticut':'Hartford',
    'Delaware':'Dover',
    'Florida': 'Tallahassee',
    'Georgia': 'Atlanta',
    'Hawaii': 'Honolulu',
    'Idaho': 'Boise',
    'Illinois': 'Springfield',
    'Indiana': 'Indianapolis',
    'Iowa': 'Des Monies',
    'Kansas': 'Topeka',
    'Kentucky': 'Frankfort',
    'Louisiana': 'Baton Rouge',
    'Maine': 'Augusta',
    'Maryland': 'Annapolis',
    'Massachusetts': 'Boston',
    'Michigan': 'Lansing',
    'Minnesota': 'St. Paul',
    'Mississippi': 'Jackson',
    'Missouri': 'Jefferson City',
    'Montana': 'Helena',
    'Nebraska': 'Lincoln',
    'Nevada': 'Carson City',
    'New Hampshire': 'Concord',
    'New Jersey': 'Trenton',
    'New Mexico': 'Santa Fe',
    'New York': 'Albany',
    'North Carolina': 'Raleigh',
    'North Dakota': 'Bismarck',
    'Ohio': 'Columbus',
    'Oklahoma': 'Oklahoma City',
    'Oregon': 'Salem',
    'Pennsylvania': 'Harrisburg',
    'Rhode Island': 'Providence',
    'South Carolina': 'Columbia',
    'South Dakoda': 'Pierre',
    'Tennessee': 'Nashville',
    'Texas': 'Austin',
    'Utah': 'Salt Lake City',
    'Vermont': 'Montpelier',
    'Virginia': 'Richmond',
    'Washington': 'Olympia',
    'West Virginia': 'Charleston',
    'Wisconsin': 'Madison',
    'Wyoming': 'Cheyenne'  
}

# %%
# Do not erase this. It is for slicing tips
wildf_dfv2.loc[wildf_dfv2['Region'].isnull(), ['Location', 'Region']].head(100)
# Out:
#                                                                                Location  \
# 6                                                                                   NaN
# 12                                                                        Ryan Carbajal
# 20                                                                       Split Mountain
# 23                                                                 23 miles from Cortez
# 26                                                                 14 mi. W. Sahuarita
# 33                                                                  Northeast of Tucson
# 40                                                                        Wildland Fire
# 53                                                              Klamath National Forest
# 56                                           3 miles East of Tusayan near FR 302 & 2709
# 61                  Selway-Bitterroot Wilderness, Nez Perce-Clearwater National Forests
# 67  Page For Emerging Initial Attack Incidents On The Humboldt-toiyabe National Forest.
# 76         4 miles south of White Wolf Campground and 1 mile west of Lukens Lake Trail
# 78                                                  Keyesville Area - Black Gulch North
# 97                                                        Peloncilo Mountain Wilderness
# 98                                                       SAN GABRIEL CYN RD/ N RANCH RD
#
#    Region
# 6     NaN
# 12    NaN
# 20    NaN
# 23    NaN
# 26    NaN
# 33    NaN
# 40    NaN
# 53    NaN
# 56    NaN
# 61    NaN
# 67    NaN
# 76    NaN
# 78    NaN
# 97    NaN
# 98    NaN

# %%
wildf_dfv2.loc[:,'Region'].isnull().all().sum()
# Out:
# 0

# %%
fire4.corr()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fire4[['Personnel Involved', 'Area Contained (Acres)']].plot(ax=ax)
fire4['Perimeter Contained (%)'].plot(secondary_y=True)
plt.legend(loc='best')
ax.set_ylabel('Personnel Involved')
ax.right_ax.set_ylabel('Perimeter')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fire4.plot(x='Region', y=['Personnel Involved', 'Area Contained (Acres)'],ax=ax)
fire4.plot(x='Region', y='Perimeter Contained (%)', secondary_y=True, ax= ax)
fig.autofmt_xdate()
ax.set_ylabel('Personnel Involved')
ax.right_ax.set_ylabel('Perimeter')

# %%
fire4.axes

# %%
fire4.index

# %%
fire4.columns

# %%
fire4.info()

# %%
from sklearn.preprocessing import minmax_scale
cols = fire4['Perimeter Contained (%)']

min_max_scaler = preprocessing.MinMaxScaler()
fire4.loc[:,'Perimeter Scaled'] = minmax_scale(fire4['Perimeter Contained (%)'])
#df_normalized = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
fire4.loc[:,'Perimeter Scaled']  = scaler.fit_transform(fire4.loc['Perimeter Contained (%)'])

# %%
unscaled = scaler.inverse_transform(fire4['Perimeter Scaled'])

# %%
min_max_scaler = preprocessing.MinMaxScaler()
fire4_scaled = min_max_scaler.fit_transform(fire4['Perimeter Contained (%)'])

# %%
fire4_scaled = preprocessing.scale(fire4['Perimeter Contained (%)'])

# %%
fire4_scaled

# %%
from sklearn.preprocessing import StandardScaler

# %%
new_inverse = scalery.inverse_transform(fire4['Perimeter Contained (%)'])
